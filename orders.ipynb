# %%
# Importing used libraries
import pandas as pd
from collections import defaultdict
from statistics import mean
import json

# %%
# Reading JSON file into a pandas DataFrame
df = pd.read_json("Order_Export.json", lines=True)

# %%
# Inspecting DataFrame Structure
df.head(5)
# Out:
#       _id                                             client  \
# 0  126531  {'id': 56468, 'name': 'DROG. SAO JUDAS', 'raza...
# 1  126517  {'id': 56638, 'name': 'DROG. COTIFARMA', 'raza...
# 2  126454  {'id': 57821, 'name': 'FARMAIS', 'razaoSocial'...
# 3  126449  {'id': 63631, 'name': 'E+FARMA ITAPEVA', 'raza...
# 4  126448  {'id': 64402, 'name': 'BRASIL GENERICOS', 'raz...
#
#                                                items
# 0  [{'product': {'sku': 'P00032604', 'name': 'VIT...
# 1  [{'product': {'sku': 'P00014022', 'name': 'EXP...
# 2  [{'product': {'sku': 'P00028545', 'name': 'VIT...
# 3  [{'product': {'sku': 'P00028541', 'name': 'ASS...
# 4  [{'product': {'sku': 'P00020620', 'name': 'NIM...

# %%
# Inspecting client column structure
df.iloc[0].loc['client']
# Out:
# {'id': 56468,
#  'name': 'DROG. SAO JUDAS',
#  'razaoSocial': 'DROGARIA SAO JUDAS DE MAUA LTDA - ME'}

# %%
# Inspecting items column structure
df.iloc[0].loc['items']
# Out:
# [{'product': {'sku': 'P00032604',
#    'name': 'VITAXON C 1G C/30CPR EFERV-LARANJ (VIT.C',
#    'maker': 'AIRELA'},
#   'quantity': 10,
#   'averagePrice': 17.36,
#   'distributorBuyingPrice': 8.31,
#   'price': 13.89},
#  {'product': {'sku': 'P00031400',
#    'name': 'VITACIN 1G C/10ENV EFE 4G-LAR (VIT.C',
#    'maker': 'GEOLAB'},
#   'quantity': 30,
#   'averagePrice': 5.84,
#   'distributorBuyingPrice': 3.31,
#   'price': 4.86},
#  {'product': {'sku': 'P00025011',
#    'name': 'BIOVITA C 1G C/50ENV EFE S/AC-LAR (VIT.C',
#    'maker': 'VITAMED'},
#   'quantity': 21,
#   'averagePrice': 35.65,
#   'distributorBuyingPrice': 18.8,
#   'price': 31.33}]

# %%
# Creating aggregating variables
margin_by_product = defaultdict(list)
margin_by_maker = defaultdict(list)
client_orders = defaultdict(list)
total = 0
min_number_of_itens = None
max_number_of_itens = None
total_num_of_itens = 0
num_of_orders = 0
total_global_margin = []

# %%
# Aggregating values for each record, its client and each of its items
for record in range(len(df)):
    client_order = 0
    num_of_orders += 1
    num_of_itens = len(df.iloc[record].loc['items'])
    total_num_of_itens += num_of_itens
    min_number_of_itens = num_of_itens if (min_number_of_itens is None or min_number_of_itens > num_of_itens) else min_number_of_itens
    max_number_of_itens = num_of_itens if (max_number_of_itens is None or max_number_of_itens < num_of_itens) else max_number_of_itens
    for product in df.iloc[record].loc['items']:
        product_data = product.get('product')
        sku = product_data.get('sku')
        name = product_data.get('name')
        maker = product_data.get('maker')
        quantity = product.get('quantity')
        price = product.get('price')
        distributorBuyingPrice = product.get('distributorBuyingPrice')
        total += price * quantity
        margin = (price - distributorBuyingPrice) / distributorBuyingPrice
        total_global_margin.append(margin)
        margin_by_product[f'{sku};{name}'].append(margin)
        margin_by_maker[maker].append(margin)
        client_order += price * quantity
    client_data = df.iloc[record].loc['client']
    client_id = client_data.get('id')
    client_name = client_data.get('name')
    client_orders[f'{client_id};{client_name}'].append(client_order)

# %%
# Structuring product margins information
productMargins = []
for sku_name, margins in margin_by_product.items():
    sku, name = sku_name.split(';')
    productMargin = {
        'sku': sku,
        'name': name,
        'margin': mean(margins)
    }
    productMargins.append(productMargin)

# %%
# Structuring maker margins information
makerMargins = []
for maker, margins in margin_by_maker.items():
    makerMargin = {
        'maker': maker,
        'margin': mean(margins)
    }
    makerMargins.append(makerMargin)

# %%
# Structuring client stats information
clientStats = []
for client_name, orders in client_orders.items():
    client_id_, name = client_name.split(';')
    singleClientStats = {
        'id': client_id,
        'name': name,
        'orderCount': len(orders),
        'orderTotal': sum(orders)
    }
    clientStats.append(singleClientStats)

# %%
# Structuring result JSON
result = {
    'salesTotal': total,
    'averageOrder': total / num_of_orders,
    'averageOrderItems': total_num_of_itens / num_of_orders,
    'minOrderItens': min_number_of_itens,
    'maxOrderItens': max_number_of_itens,
    'globalMargin': mean(total_global_margin),
    'productMargins': productMargins,
    'makerMargins': makerMargins,
    'clientStats': clientStats
}

# %%
# Writing result JSON to a file
with open('result_orders.json', 'w') as result_file:
    json.dump(result, result_file)

# %%
# Printing result JSON
print(json.dumps(result, indent=2))
# Out:
# {
#   "salesTotal": 1289421.6299999084,
#   "averageOrder": 1289.4216299999084,
#   "averageOrderItems": 17.704,
#   "minOrderItens": 0,
#   "maxOrderItens": 158,
#   "globalMargin": 0.6847010815583214,
#   "productMargins": [
#     {
#       "sku": "P00032604",
#       "name": "VITAXON C 1G C/30CPR EFERV-LARANJ (VIT.C",
#       "margin": 0.6714801444043321
#     },
#     {
#       "sku": "P00031400",
#       "name": "VITACIN 1G C/10ENV EFE 4G-LAR (VIT.C",
#       "margin": 0.46827794561933545
#     },
#     {
#       "sku": "P00025011",
#       "name": "BIOVITA C 1G C/50ENV EFE S/AC-LAR (VIT.C",
#       "margin": 0.6664893617021275
#     },
#     {
#       "sku": "P00014022",
#       "name": "EXPEC XPE 120ML (GUAI+IOD.POT+BENZ.SOD+O",
#       "margin": 0.380103550295858
#     },
#     {
#       "sku": "P00030475",
#       "name": "DIGOXINA 0,25MG C/20CPR (GEN)",
#       "margin": 0.7259615384615383
#     },
#     {
#       "sku": "P00022787",
#       "name": "ENXAK C/12CPR (DIPIRONA+CAF+DI-HIDROERG",
#       "margin": 0.4747372845733501
#     },
#     {
#       "sku": "P00027942",
#       "name": "HISTAMIN 10MG/G CR 30G (DEXCLORFENIRAMIN",
#       "margin": 0.5391642371234208
#     },
#     {
#       "sku": "P00031587",
#       "name": "LAVITAN MAIS HAIR C/60CPS (POLIVIT+POLIM",
#       "margin": 1.0186447094453908
#     },
#     {
#       "sku": "P00028652",
#       "name": "LAVITAN MULHER C/60CPR (POLIVIT+POLIM",
#       "margin": 1.1443841671689772
#     },
#     {
#       "sku": "P00024137",
#       "name": "NEOLEFRIN XPE 60ML (PARAC+FENILEF+CAR",
#       "margin": 0.5800875273522975
#     },
#     {
#       "sku": "P00026030",
#       "name": "EXPECTAMIN SOL OR 120ML (DEXCLOR+PSEU+GU",
#       "margin": 0.7121999505073001
#     },
#     {
#       "sku": "P00026408",
#       "name": "DEXAMETASONA 4MG C/10CPR (GEN)",
#       "margin": 0.5891358024691358
#     },
#     {
#       "sku": "P00024816",
#       "name": "TYFLEN BEBE 100MG/ML SUSP 15ML-CEREJ(PAR",
#       "margin": 0.7003732006397725
#     },
#     {
#       "sku": "P00023585",
#       "name": "TYLEMAX 200MG/ML 15ML-TUTTI-FRUT (PARACE",
#       "margin": 0.4745639534883721
#     },
#     {
#       "sku": "P00012205",
#       "name": "RESFENOL C/ 20CPS (PARAC+CLORFEN+FENILEF",
#       "margin": 0.5591681312243701
#     },
#     {
#       "sku": "P00026145",
#       "name": "SEAKALM 260MG C/20CPR REV (PASSIFLORA)",
#       "margin": 0.4296461926174828
#     },
#     {
#       "sku": "P00028405",
#       "name": "SEAKALM 90MG/ML SOL OR 100ML (PASSIFLORA",
#       "margin": 0.653210607056761
#     },
#     {
#       "sku": "P00019422",
#       "name": "CETOBETA CR 30G (CETOCON+BETAM+NEOM",
#       "margin": 0.7928919030855252
#     },
#     {
#       "sku": "P00019518",
#       "name": "CETOBETA PDA 30G (CETOCON+BETAM+NEOM",
#       "margin": 0.7956989247311828
#     },
#     {
#       "sku": "P00025191",
#       "name": "FOLIFOLIN 5MG C/ 30CPR (ACIDO FOLICO)",
#       "margin": 0.7466216216216217
#     },
#     {
#       "sku": "P00013212",
#       "name": "PIOLETAL 1% LOCAO 60ML (PERMETRINA)",
#       "margin": 0.637773722627737
#     },
#     {
#       "sku": "P00020866",
#       "name": "GLICONIL 5MG C/30CPR (GLIBENCLAMIDA)",
#       "margin": 0.5244444444444444
#     },
#     {
#       "sku": "P00025040",
#       "name": "ENALAPRIL 10MG C/30CPR (GEN)",
#       "margin": 0.852112676056338
#     },
#     {
#       "sku": "P00024910",
#       "name": "HEMODASE PDA 25G+10APL (HIDR+LID+BIS+ZIN",
#       "margin": 0.6070363744782349
#     },
#     {
#       "sku": "P00028545",
#       "name": "VITER C 1G C/10CPR EFERV-LARANJA (VIT.C)",
#       "margin": 0.5020551175796779
#     },
#     {
#       "sku": "P00028541",
#       "name": "ASSEPMED 1% SOL TOP 30ML (CLOREXIDINA)",
#       "margin": 0.6311475409836067
#     },
#     {
#       "sku": "P00018919",
#       "name": "BENZODERM 10% SAB 60G (BENZILA)",
#       "margin": 0.49110953058321494
#     },
#     {
#       "sku": "P00030055",
#       "name": "CAMOMINE C BABY C/20CPS-CAMOM/FUNCH (VIT",
#       "margin": 1.0711225364181662
#     },
#     {
#       "sku": "P00021377",
#       "name": "CIMEGRIPE GTS 20ML (PARAC+FENILEF+CLORF",
#       "margin": 1.0465709728867625
#     },
#     {
#       "sku": "P00028093",
#       "name": "DORDENTE C/24FLAC 3ML (PROCAINA+FENOL+ME",
#       "margin": 0.8212666807879686
#     },
#     {
#       "sku": "P00029863",
#       "name": "HEMOFISS PDA 30G+APL (HIDROC+LIDOC+BISM+",
#       "margin": 0.5699537557805275
#     },
#     {
#       "sku": "P00029517",
#       "name": "HORA H UNO 1,5MG C/1CPR (LEVONORGESTREL)",
#       "margin": 0.5075949367088607
#     },
#     {
#       "sku": "P00029590",
#       "name": "IBUVIX 300MG C/30CPR (IBUPROFENO)",
#       "margin": 0.585185185185185
#     },
#     {
#       "sku": "P00032186",
#       "name": "LIMP LENT KIT 350ML (GR.FR 120ML+ESTOJO)",
#       "margin": 0.4890477720651242
#     },
#     {
#       "sku": "P00020403",
#       "name": "PEDIDERM 0,2MG/ML SHAMPOO 100ML (DELTAM",
#       "margin": 0.6461458197469675
#     },
#     {
#       "sku": "P00011705",
#       "name": "SANASAR 0,1G/G SAB 80G (BENZILA)",
#       "margin": 0.3972248874455679
#     },
#     {
#       "sku": "P00032025",
#       "name": "SULFATO FERROSO 125MG/ML GTS 30ML-FRAMB",
#       "margin": 1.4390243902439026
#     },
#     {
#       "sku": "P00031629",
#       "name": "SULFERROL C/50TABL (SULF.FERROSO)",
#       "margin": 0.7727520435967303
#     },
#     {
#       "sku": "P00024530",
#       "name": "CONFIRA TESTE DE GRAVIDEZ KIT",
#       "margin": 0.9282051282051281
#     },
#     {
#       "sku": "P00021504",
#       "name": "VERTIZAN 10MG C/50CPR (FLUNARIZINA)",
#       "margin": 0.6643939393939395
#     },
#     {
#       "sku": "P00025710",
#       "name": "BENZIFLEX 10MG C/30CPR REV (CICLOBENZAPR",
#       "margin": 0.6302414231257941
#     },
#     {
#       "sku": "P00011267",
#       "name": "EMISTIN CR 20G (CLEMASTINA+DEXAMETASONA)",
#       "margin": 0.748101793909053
#     },
#     {
#       "sku": "P00031455",
#       "name": "ACICLOVIR 200MG C/25CPR (GEN)",
#       "margin": 1.0231109324758845
#     },
#     {
#       "sku": "P00031132",
#       "name": "DEXCLORFENIRAMINA 0,4MG/ML SOL 120ML(GEN",
#       "margin": 0.7083564943487121
#     },
#     {
#       "sku": "P00024213",
#       "name": "DICLOF.DIETILAMONIO 11,6MG/G GEL 60G(GEN",
#       "margin": 0.8271338724168914
#     },
#     {
#       "sku": "P00030215",
#       "name": "FINASTERIDA 1MG C/30CPR REV (GEN)",
#       "margin": 0.6870689655172415
#     },
#     {
#       "sku": "P00026291",
#       "name": "IVERMECTINA 6MG C/ 4CPR (GEN)",
#       "margin": 0.6986534592168395
#     },
#     {
#       "sku": "P00024307",
#       "name": "TIMOLOL 0,5% SOL OFT 5ML (GEN)",
#       "margin": 0.5983974358974359
#     },
#     {
#       "sku": "P00020548",
#       "name": "CIMEGRIPE C/ 20CPS (PARAC+FENIL+CLOR",
#       "margin": 0.746955624355005
#     },
#     {
#       "sku": "P00020620",
#       "name": "NIMELIT 100MG C/12CPR (NIMESULIDA)",
#       "margin": 1.0194871794871794
#     },
#     {
#       "sku": "P00032255",
#       "name": "ALENDRONATO DE SODIO 70MG C/ 4CPR (GEN)",
#       "margin": 0.8339160839160839
#     },
#     {
#       "sku": "P00022219",
#       "name": "PROFERGAN 25MG C/20CPR REV (PROMETAZINA)",
#       "margin": 0.6406250000000001
#     },
#     {
#       "sku": "P00010595",
#       "name": "HISTAMIN 2MG C/20CPR (DEXCLORFENIRAMINA)",
#       "margin": 0.4977747440273037
#     },
#     {
#       "sku": "P00025886",
#       "name": "ONCILEG-A 1MG/G PAST BUCAL 10G (TRIANCIN",
#       "margin": 0.7551801801801803
#     },
#     {
#       "sku": "P00030486",
#       "name": "LABCAINA 20MG/G GELEIA 30G-URETRAL(LIDOC",
#       "margin": 0.6009174311926606
#     },
#     {
#       "sku": "P00020275",
#       "name": "PROMERGAN 20MG/G CR 30G (PROMETAZINA)",
#       "margin": 1.594469582704877
#     },
#     {
#       "sku": "P00030867",
#       "name": "CARVEDILOL  6,25MG C/30CPR (GEN)",
#       "margin": 1.298507462686567
#     },
#     {
#       "sku": "P00032294",
#       "name": "CETOCONAZOL+BETAM+NEOM PDA 30G (GEN)",
#       "margin": 0.7558441558441558
#     },
#     {
#       "sku": "P00030019",
#       "name": "CARDBET 25MG C/30CPR (CARVEDILOL)",
#       "margin": 0.6193853427895979
#     },
#     {
#       "sku": "P00024074",
#       "name": "ACEBROFILINA 10MG/ML XPE AD 120ML (GEN)",
#       "margin": 0.5351473922902493
#     },
#     {
#       "sku": "P00024281",
#       "name": "CETOCONAZOL+BETAM+NEOM CR 30G (GEN)",
#       "margin": 0.49565217391304356
#     },
#     {
#       "sku": "P00029548",
#       "name": "CETOCONAZOL+BETAM+NEOM PDA 30G (GEN)",
#       "margin": 0.4354545454545454
#     },
#     {
#       "sku": "P00032340",
#       "name": "ORALDRAT PO C/4ENV C/28G-NATURAL (REIDRA",
#       "margin": 0.9653579676674364
#     },
#     {
#       "sku": "P00029744",
#       "name": "CARVEDILOL 25MG C/30CPR (GEN)",
#       "margin": 0.7877094972067038
#     },
#     {
#       "sku": "P00029778",
#       "name": "BRONQUIVITA XPE 150ML (TINTURA EUCALIPTO",
#       "margin": 1.0510265700483095
#     },
#     {
#       "sku": "P00029701",
#       "name": "BETAISTINA 24MG C/30CPR (GEN)",
#       "margin": 0.6571207430340558
#     },
#     {
#       "sku": "P00031403",
#       "name": "BENZIFLEX LIS 125+5MG C/15CPR REV",
#       "margin": 0.803587962962963
#     },
#     {
#       "sku": "P00028929",
#       "name": "BRIMONIDINA 2MG/ML SOL OFT 5ML (GEN)",
#       "margin": 0.3639575971731449
#     },
#     {
#       "sku": "P00031667",
#       "name": "BIO PANTOVIT C/60FLAC 10ML-BOLDO(COLINA+",
#       "margin": 0.7165796344647521
#     },
#     {
#       "sku": "P00021744",
#       "name": "BECLONATO INJ 1AMP/1ML+SER",
#       "margin": 0.4366379310344829
#     },
#     {
#       "sku": "P00031589",
#       "name": "DORALEX 500MG C/200CPR-20X10 (DIPIRONA)",
#       "margin": 0.6704157549234134
#     },
#     {
#       "sku": "P00019244",
#       "name": "LORATAMED 1MG/ML XPE 100ML (LORATADINA)",
#       "margin": 0.6449778706663389
#     },
#     {
#       "sku": "P00026271",
#       "name": "TORSILAX  C/12CPR(PARAC+DICLOF+CARIS+CAF",
#       "margin": 0.6044733538742441
#     },
#     {
#       "sku": "P00019180",
#       "name": "TORSILAX  C/30CPR(PARAC+DICLOF+CARIS+CAF",
#       "margin": 0.5061653116531164
#     },
#     {
#       "sku": "P00025684",
#       "name": "CONFIRME COMPACT C/1 TESTE (CANETA)",
#       "margin": 1.2771626297577854
#     },
#     {
#       "sku": "P00022182",
#       "name": "FLOMICIN 200MG 4ENV 1G",
#       "margin": 0.6231404958677687
#     },
#     {
#       "sku": "P00031266",
#       "name": "VENAFLON 450/50MG C/60CPR REV(DIOSM+HESP",
#       "margin": 0.5617042115572969
#     },
#     {
#       "sku": "P00022201",
#       "name": "BENEUM 300MG C/30CPR REV (VIT.B1)",
#       "margin": 0.5545755237045203
#     },
#     {
#       "sku": "P00032022",
#       "name": "SIMETICONA  40MG C/20CPR (GEN)",
#       "margin": 0.6748595505617978
#     },
#     {
#       "sku": "P00029028",
#       "name": "HIDROXIZINA 2MG/ML SOL 100ML (GEN)",
#       "margin": 0.6483516483516483
#     },
#     {
#       "sku": "P00029872",
#       "name": "HIDROXIZINA 25MG C/30CPR (GEN)",
#       "margin": 0.6518934665002081
#     },
#     {
#       "sku": "P00031464",
#       "name": "PIROXICAM 20MG C/15CPS (GEN)",
#       "margin": 0.7980487804878051
#     },
#     {
#       "sku": "P00013475",
#       "name": "COLIRIO TEUTO SOL OFT 20ML (NAFAZ+ZINCO)",
#       "margin": 0.6446243814664868
#     },
#     {
#       "sku": "P00023241",
#       "name": "FUROSEMIDA 40MG C/20CPR (GEN)",
#       "margin": 0.7386148007590134
#     },
#     {
#       "sku": "P00014038",
#       "name": "BISMU-JET GTS 20ML (NEOMIC+BISMUT+SOD+PR",
#       "margin": 0.43096577590248464
#     },
#     {
#       "sku": "P00011226",
#       "name": "NARIDRIN AD 15ML (NAFAZ+MEPIRAM+D-PANTEN",
#       "margin": 0.7263696568332331
#     },
#     {
#       "sku": "P00019316",
#       "name": "NEO FEDIPINA 20MG C/30CPR (NIFEDIPINO)",
#       "margin": 0.60849478390462
#     },
#     {
#       "sku": "P00010548",
#       "name": "NEO FEDIPINA 10MG C/30CPR (NIFEDIPINO)",
#       "margin": 0.19540946149452146
#     },
#     {
#       "sku": "P00029568",
#       "name": "MICONAZOL 20MG/G CR 28G (GEN)",
#       "margin": 0.6530337078651685
#     },
#     {
#       "sku": "P00018213",
#       "name": "DEXAMEX 1MG/G CR 10G (DEXAMETASONA)",
#       "margin": 0.6238651102464332
#     },
#     {
#       "sku": "P00031998",
#       "name": "APIS FRESH EXTRA FORTE SPRAY 35ML",
#       "margin": 0.5714285714285716
#     },
#     {
#       "sku": "P00029733",
#       "name": "LAVITAN 50+ C/60CPR (POLIVIT+POLIM",
#       "margin": 0.745224541429475
#     },
#     {
#       "sku": "P00031664",
#       "name": "COMPLEXO B C/100CPR REV",
#       "margin": 1.17324470294973
#     },
#     {
#       "sku": "P00024327",
#       "name": "NEVRALGEX C/100CPR-10X10(DIPIRONA+CAF+OR",
#       "margin": 0.5104039292410533
#     },
#     {
#       "sku": "P00019865",
#       "name": "DERMOSALIC PDA 30G (BETAMET+AC.SALICILIC",
#       "margin": 0.7466023875114786
#     },
#     {
#       "sku": "P00022946",
#       "name": "DIAD 0,75MG C/2CPR (PILULA D/S)",
#       "margin": 0.6926886792452829
#     },
#     {
#       "sku": "P00030471",
#       "name": "CETOCONAZOL 200MG C/10CPR (GEN)",
#       "margin": 0.6780598958333333
#     },
#     {
#       "sku": "P00026099",
#       "name": "AMOX+CLAV.POT.400+57MG/5ML SUSP 70ML(GEN",
#       "margin": 0.5366868381240544
#     },
#     {
#       "sku": "P00011257",
#       "name": "NARIDRIN AD 30ML 12H (NAFAZ+MEPIRAM+D-PA",
#       "margin": 0.5444078947368419
#     },
#     {
#       "sku": "P00023250",
#       "name": "PARACETAMOL 750MG C/ 20CPR (GEN)",
#       "margin": 0.5593270365997639
#     },
#     {
#       "sku": "P00023993",
#       "name": "LORATADINA 1MG/ML XPE 100ML (GEN)",
#       "margin": 0.712038789025544
#     },
#     {
#       "sku": "P00021914",
#       "name": "FLUXON 75MG C/30CPR (CINARIZINA)",
#       "margin": 0.5944112108120083
#     },
#     {
#       "sku": "P00021547",
#       "name": "ATENOLOL  50MG C/30CPR REV (GEN)",
#       "margin": 0.5575916230366491
#     },
#     {
#       "sku": "P00019435",
#       "name": "CIFLOGEX C/12PAST-MEL/LIMAO (BENZIDA",
#       "margin": 0.7816612128385435
#     },
#     {
#       "sku": "P00021376",
#       "name": "CIFLOGEX COLUT SPRAY 30ML-MEL (BENZIDAM.",
#       "margin": 0.6842911877394636
#     },
#     {
#       "sku": "P00021375",
#       "name": "CIFLOGEX COLUT SPRAY 30ML-MENTA (BENZID.",
#       "margin": 0.8094451328652073
#     },
#     {
#       "sku": "P00029124",
#       "name": "COLCHICINA 0,5MG C/30CPR (GEN)",
#       "margin": 0.7241300366300366
#     },
#     {
#       "sku": "P00026636",
#       "name": "ALOPURINOL 100MG C/30CPR (GEN)",
#       "margin": 0.6000394632991317
#     },
#     {
#       "sku": "P00020936",
#       "name": "ARTRITEC 15MG C/10CPR (MELOXICAM)",
#       "margin": 0.9955
#     },
#     {
#       "sku": "P00020160",
#       "name": "NEBACTRINA PDA 10G",
#       "margin": 0.6632727272727272
#     },
#     {
#       "sku": "P00024508",
#       "name": "CORTIDEX 1MG/G CR 10G",
#       "margin": 0.519736842105263
#     },
#     {
#       "sku": "P00024522",
#       "name": "TRICORTID CR 30G (CETOCON+BETAM+NEOM",
#       "margin": 0.7232142857142856
#     },
#     {
#       "sku": "P00024521",
#       "name": "TRICORTID PDA 30G (CETOCON+BETAM+NEOM",
#       "margin": 0.7464285714285714
#     },
#     {
#       "sku": "P00024214",
#       "name": "PLESONAX 5MG C/ 20CPR REV (BISACODIL)",
#       "margin": 0.5630961115187089
#     },
#     {
#       "sku": "P00029539",
#       "name": "ACETILCISTEINA 20MG/ML XPE 120ML (GEN)",
#       "margin": 0.6043175891046074
#     },
#     {
#       "sku": "P00032023",
#       "name": "COMPLEXO B SOL 100ML (VIT.COMPL.B)",
#       "margin": 0.9006493506493505
#     },
#     {
#       "sku": "P00019743",
#       "name": "NOCICLIN C/21CPR (ANTICONCEPCIONAL)",
#       "margin": 0.5813953488372094
#     },
#     {
#       "sku": "P00023046",
#       "name": "REPOPIL 35 C/21CPR REV (CIPROTERONA+ETIN",
#       "margin": 0.5943334065451351
#     },
#     {
#       "sku": "P00023044",
#       "name": "PREVIANE C/21CPR REV (ANTICONCEPCIONAL)",
#       "margin": 0.6616460462614308
#     },
#     {
#       "sku": "P00027434",
#       "name": "CICLOBENZAPRINA  5MG C/15CPR REV (GEN)",
#       "margin": 0.6002178649237473
#     },
#     {
#       "sku": "P00027467",
#       "name": "HIDROXIZINA 25MG C/30CPR (GEN)",
#       "margin": 0.6073932441045251
#     },
#     {
#       "sku": "P00024839",
#       "name": "CIMECORT CR 15G (CETOCON+BETAM+NEOM",
#       "margin": 0.6581508515815084
#     },
#     {
#       "sku": "P00018826",
#       "name": "DORALGINA C/ 20DRG (ISOMET+DIPIR+CAF",
#       "margin": 0.6076030927835053
#     },
#     {
#       "sku": "P00020547",
#       "name": "NEOSORO AD SOL NASAL 30ML (NAFAZOLINA)",
#       "margin": 0.28311928728450786
#     },
#     {
#       "sku": "P00024995",
#       "name": "NEOSORO INF SOL NASAL 30ML (CLOR.SODIO)",
#       "margin": 0.4489852398523985
#     },
#     {
#       "sku": "P00014346",
#       "name": "COLPADAK 20MG/G CR 28G (MICONAZOL)",
#       "margin": 1.9876190476190478
#     },
#     {
#       "sku": "P00018133",
#       "name": "COLPADAK 20MG/ML LOCAO 30ML (MICONAZOL)",
#       "margin": 1.933712121212121
#     },
#     {
#       "sku": "P00026115",
#       "name": "NARIX 0,5MG/ML AD SOL NAS 30ML (NAFAZOL",
#       "margin": 0.4939860139860139
#     },
#     {
#       "sku": "P00028874",
#       "name": "TANDENE C/15CPR (PARAC+DICLOF+CARIS+CAF",
#       "margin": 0.6064650809716599
#     },
#     {
#       "sku": "P00018894",
#       "name": "TANDENE C/30CPR (PARAC+DICLOF+CARIS+CAF",
#       "margin": 0.6090236402075726
#     },
#     {
#       "sku": "P00024766",
#       "name": "ACNEZIL 5% GEL 20G (PEROXIDO BENZOILA)",
#       "margin": 0.6764008921103988
#     },
#     {
#       "sku": "P00021805",
#       "name": "CIMECORT CR 30G (CETOCON+BETAM+NEOM",
#       "margin": 0.48132530120481937
#     },
#     {
#       "sku": "P00020730",
#       "name": "CIMELIDE 100MG C/12CPR (NIMESULIDA)",
#       "margin": 0.6112119013062408
#     },
#     {
#       "sku": "P00028379",
#       "name": "HIDROCLOROTIAZIDA 25MG C/30CPR (GEN)",
#       "margin": 0.9985815602836878
#     },
#     {
#       "sku": "P00030795",
#       "name": "OLEO DE RICINO 100% 30ML",
#       "margin": 0.6124661246612464
#     },
#     {
#       "sku": "P00032030",
#       "name": "CONFIRME SEMANAS C/1 TESTE",
#       "margin": 0.8629588431590657
#     },
#     {
#       "sku": "P00027504",
#       "name": "BETAMETASONA+AC.SALICILICO SOL 30ML (GEN",
#       "margin": 1.0604212860310422
#     },
#     {
#       "sku": "P00022773",
#       "name": "ACFOL 5MG/ML GTS 10ML (ACIDO FOLICO)",
#       "margin": 0.3733552631578947
#     },
#     {
#       "sku": "P00028944",
#       "name": "ATENOLOL  25MG C/30CPR (GEN)",
#       "margin": 0.7545893719806762
#     },
#     {
#       "sku": "P00023221",
#       "name": "BROMOPRIDA 4MG/ML SOL 20ML (GEN)",
#       "margin": 0.7470817120622567
#     },
#     {
#       "sku": "P00021808",
#       "name": "VALERIMED 50MG C/20CPR REV (VALERIANA)",
#       "margin": 0.754900515843773
#     },
#     {
#       "sku": "P00023236",
#       "name": "DEXCLORF+BETAMETASONA XPE 120ML (GEN)",
#       "margin": 0.5838659907427814
#     },
#     {
#       "sku": "P00031141",
#       "name": "SIMETICONA  75MG/ML GTS 15ML (GEN)",
#       "margin": 0.7323333333333334
#     },
#     {
#       "sku": "P00028132",
#       "name": "LAVITAN A-Z C/60CPR (POLIVIT+POLIM.",
#       "margin": 0.9217079689018465
#     },
#     {
#       "sku": "P00022544",
#       "name": "CETOPROFENO 50MG C/24CPS (GEN)",
#       "margin": 0.65633423180593
#     },
#     {
#       "sku": "P00025456",
#       "name": "INFRALAX C/ 15CPR (PARAC+ASS",
#       "margin": 0.556184634740898
#     },
#     {
#       "sku": "P00022313",
#       "name": "INFRALAX C/ 30CPR (PARAC+ASS",
#       "margin": 0.6308329351807612
#     },
#     {
#       "sku": "P00020865",
#       "name": "TENOXIL 20MG C/10CPR REV (TENOXICAM)",
#       "margin": 0.6452546296296295
#     },
#     {
#       "sku": "P00032673",
#       "name": "CETOCONAZOL+BETAM+NEOM CR 30G (GEN)",
#       "margin": 1.0749120160884869
#     },
#     {
#       "sku": "P00031927",
#       "name": "SIMETICONA  40MG C/20CPR",
#       "margin": 0.5771604938271604
#     },
#     {
#       "sku": "P00029995",
#       "name": "VARIVAX 300MG C/30CPR REV (CASTANHA INDI",
#       "margin": 0.18844874194219172
#     },
#     {
#       "sku": "P00023215",
#       "name": "VENAFLON 450/50MG C/30CPR REV(DIOSM+HESP",
#       "margin": 0.48860960313328866
#     },
#     {
#       "sku": "P00029842",
#       "name": "HEMOCORT PDA 25G (HIDROC+LIDOC+BISM+ZIN",
#       "margin": 0.6931216931216932
#     },
#     {
#       "sku": "P00024791",
#       "name": "AGUA OXIGENADA 10 VOL 1L-RIOQUIMICA",
#       "margin": 0.818867924528302
#     },
#     {
#       "sku": "P00023813",
#       "name": "FITA MICROP. 50MM X 4,5M HIPOALERGICA",
#       "margin": 0.46372067648663395
#     },
#     {
#       "sku": "P00023804",
#       "name": "ESPARADRAPO  1,2CM X 4,5M-IMPERMEAVEL",
#       "margin": 0.4980620155038759
#     },
#     {
#       "sku": "P00023803",
#       "name": "ESPARADRAPO IMPER.SANF. 50MM X 4,5M-BRAN",
#       "margin": 0.3333333333333333
#     },
#     {
#       "sku": "P00022178",
#       "name": "NAPRONAX 550MG C/10CPR REV (NAPROXENO)",
#       "margin": 0.6870118035063356
#     },
#     {
#       "sku": "P00020782",
#       "name": "BELFAREN 50MG C/20CPR REV (DICLOF.SODICO",
#       "margin": 0.8421717171717171
#     },
#     {
#       "sku": "P00019434",
#       "name": "CIFLOGEX C/12PAST-CEREJA (BENZIDAMINA)",
#       "margin": 0.6405463695183322
#     },
#     {
#       "sku": "P00019433",
#       "name": "CIFLOGEX C/12PAST-LARANJA (BENZIDAMINA)",
#       "margin": 0.5984326018808778
#     },
#     {
#       "sku": "P00032759",
#       "name": "FLUCONAZOL 150MG C/2CPS (GEN)",
#       "margin": 0.8842105263157893
#     },
#     {
#       "sku": "P00027804",
#       "name": "PROCTOSAN PDA 20G+6APL (HIDROCORT+ASSOC",
#       "margin": 0.5643863179074446
#     },
#     {
#       "sku": "P00020879",
#       "name": "LORATAMED 10MG C/12CPR (LORATADINA)",
#       "margin": 0.6308650065530798
#     },
#     {
#       "sku": "P00031433",
#       "name": "MAXALGINA 500MG C/ 30CPR (DIPIRONA)",
#       "margin": 0.5360892388451443
#     },
#     {
#       "sku": "P00026278",
#       "name": "NEOCOPAN 10+250MG C/20CPR REV (ESCOP+DIP",
#       "margin": 0.2983187134502923
#     },
#     {
#       "sku": "P00031960",
#       "name": "AFT RUB SPRAY BUCAL 30ML (ROSA RUBRA)",
#       "margin": 0.6271130261849521
#     },
#     {
#       "sku": "P00032171",
#       "name": "TADALAFILA 20MG C/ 4CPR REV (GEN)",
#       "margin": 0.7797157622739018
#     },
#     {
#       "sku": "P00013006",
#       "name": "VITAMINA C 500MG C/20CPR (AC.ASCORBICO)",
#       "margin": 0.6505882352941177
#     },
#     {
#       "sku": "P00032434",
#       "name": "DESPACK 13 LITROS",
#       "margin": 0.7805810397553515
#     },
#     {
#       "sku": "P00028495",
#       "name": "GRIPINEW 150CPR REV-25X6 (DIPIR+CAF+CLOR",
#       "margin": 0.5640911121036176
#     },
#     {
#       "sku": "P00031126",
#       "name": "LAVITAN MEMORIA C/60CPR",
#       "margin": 0.9609810479375694
#     },
#     {
#       "sku": "P00019043",
#       "name": "BENZODERM 0,25G/ML EMUL 100ML (BENZILA)",
#       "margin": 0.6908611300204223
#     },
#     {
#       "sku": "P00030545",
#       "name": "VITA PREMIUM MULHER C/60CPR REV (A-Z)",
#       "margin": 1.675324675324675
#     },
#     {
#       "sku": "P00032139",
#       "name": "MACA PERUANA 500MG C/60CPS",
#       "margin": 0.6883484162895929
#     },
#     {
#       "sku": "P00023313",
#       "name": "FORMYN AD 1G C/30CPR REV (METFORMINA)",
#       "margin": 0.6669650850492391
#     },
#     {
#       "sku": "P00031930",
#       "name": "PREDNISOLONA  20MG C/10CPR (GEN)",
#       "margin": 0.6666666666666666
#     },
#     {
#       "sku": "P00024040",
#       "name": "PANTOPRAZOL 40MG C/28CPR REV LIB.RET(GEN",
#       "margin": 0.6337792642140467
#     },
#     {
#       "sku": "P00021179",
#       "name": "BACTRONEO 20MG/G PDA 15G (MUPIROCINA)",
#       "margin": 0.6415566407427503
#     },
#     {
#       "sku": "P00029894",
#       "name": "ACICLOVIR 200MG C/25CPR (GEN)",
#       "margin": 0.6887482419127988
#     },
#     {
#       "sku": "P00030197",
#       "name": "ACICLOVIR 400MG C/30CPR (GEN)",
#       "margin": 1.0840032154340837
#     },
#     {
#       "sku": "P00031115",
#       "name": "ANLODIPINO  5MG C/30CPR (GEN)",
#       "margin": 0.9066590779738192
#     },
#     {
#       "sku": "P00026584",
#       "name": "CIPROFIBRATO 100MG C/30CPR (GEN)",
#       "margin": 0.4093567251461989
#     },
#     {
#       "sku": "P00028410",
#       "name": "RAPILAX 7,5MG/ML GTS 30ML (PICOS.SODIO)",
#       "margin": 0.36236391912908245
#     },
#     {
#       "sku": "P00032194",
#       "name": "LACPLUS 120ML-AMEIXA (LACTULOSE)",
#       "margin": 0.6547036432843938
#     },
#     {
#       "sku": "P00025066",
#       "name": "CIMEGRIPE 77C C/50 ENV 5G MEL/LIM (PARA",
#       "margin": 0.616105190787212
#     },
#     {
#       "sku": "P00028653",
#       "name": "LAVITAN CABELOS E UNHAS C/30CPS",
#       "margin": 0.9119030303030303
#     },
#     {
#       "sku": "P00028300",
#       "name": "LAVITAN CALCIO+D C/60CPR (CALCIO+VIT.D3",
#       "margin": 0.968759342301943
#     },
#     {
#       "sku": "P00031894",
#       "name": "LAVITAN KIDS 240ML-LARANJA",
#       "margin": 0.9501412664118333
#     },
#     {
#       "sku": "P00021344",
#       "name": "OSSOTRAT-D 600+D C/60CPR REV (CALC+VIT.D",
#       "margin": 0.5121040723981899
#     },
#     {
#       "sku": "P00020964",
#       "name": "CLEARTOP 20MG/ML SHAMPOO 100ML (CETOCON",
#       "margin": 0.6486743550112948
#     },
#     {
#       "sku": "P00019233",
#       "name": "PROBENXIL 11,6MG/G GEL 60G(DICLOF.DIETIL",
#       "margin": 1.2608142493638677
#     },
#     {
#       "sku": "P00023375",
#       "name": "MEME CREME 50G (LANOLINA)",
#       "margin": 0.7453571428571428
#     },
#     {
#       "sku": "P00018063",
#       "name": "CENEVIT  1G C/10CPR EFE S/AC-LAR (VIT.C)",
#       "margin": 0.8700166112956811
#     },
#     {
#       "sku": "P00032530",
#       "name": "ALGODAO APOLO CX  25G",
#       "margin": 0.44881889763779514
#     },
#     {
#       "sku": "P00032528",
#       "name": "ALGODAO APOLO CX  50G",
#       "margin": 0.5382882882882881
#     },
#     {
#       "sku": "P00032531",
#       "name": "ALGODAO APOLO ROLO 500G",
#       "margin": 0.6124401913875597
#     },
#     {
#       "sku": "P00027278",
#       "name": "TRIANCINOLONA 1MG/G PDA BUCAL 10G (GEN)",
#       "margin": 0.6370738636363636
#     },
#     {
#       "sku": "P00031655",
#       "name": "FITA CIRUR.MICROP.HIP.2,5CM X 4,5M-BEGE",
#       "margin": 0.6703910614525139
#     },
#     {
#       "sku": "P00015553",
#       "name": "NEMICINA 3,5MG/G PDA 20G (NEOMICINA)",
#       "margin": 0.7069825436408979
#     },
#     {
#       "sku": "P00022824",
#       "name": "PIOLETAL PLUS 50MG/ML LOCAO 60ML (PERMET",
#       "margin": 0.70991890205864
#     },
#     {
#       "sku": "P00031738",
#       "name": "PROTOKIDS BB GTS 20ML-TUTTI-FRUTTI",
#       "margin": 0.8008771929824562
#     },
#     {
#       "sku": "P00028231",
#       "name": "BUPROVIL 600MG C/20CPR REV (IBUPROFENO)",
#       "margin": 0.5887419871794871
#     },
#     {
#       "sku": "P00030932",
#       "name": "TYFLEN 500MG C/ 20CPR (PARACETAMOL)",
#       "margin": 0.3621262458471762
#     },
#     {
#       "sku": "P00025666",
#       "name": "AMOXICILINA 500MG C/21CPS (GEN)",
#       "margin": 0.98224043715847
#     },
#     {
#       "sku": "P00024705",
#       "name": "AGUA BORICADA 3% SOL 100ML-FARMAX",
#       "margin": 0.7514044943820225
#     },
#     {
#       "sku": "P00020767",
#       "name": "CIMELIDE 50MG/ML GTS 15ML (NIMESULIDA)",
#       "margin": 0.8227874276261375
#     },
#     {
#       "sku": "P00021102",
#       "name": "DORILEN GTS 15ML (DIPIRONA+ADIFEN+PROMET",
#       "margin": 0.7391495601173019
#     },
#     {
#       "sku": "P00026279",
#       "name": "NEOCOPAN GTS 20ML (ESCOPOLAMINA+DIPIRONA",
#       "margin": 0.720679012345679
#     },
#     {
#       "sku": "P00028309",
#       "name": "GRIPINEW  20CPR REV (DIPIR+CAF+CLORFE",
#       "margin": 0.6111929307805596
#     },
#     {
#       "sku": "P00022959",
#       "name": "AS-MED INF 100MG C/200CPR-10X20 (AAS)",
#       "margin": 0.49336384439359265
#     },
#     {
#       "sku": "P00020757",
#       "name": "CAPTOSEN 50MG C/30 CPR (CAPTOPRIL)",
#       "margin": 0.8086956521739133
#     },
#     {
#       "sku": "P00021309",
#       "name": "OCYLIN 500MG C/21CPS (AMOXICILINA)",
#       "margin": 0.9484126984126984
#     },
#     {
#       "sku": "P00011208",
#       "name": "CYSTEX C/24DRG",
#       "margin": 0.25545993699734265
#     },
#     {
#       "sku": "P00014319",
#       "name": "MICOSBEL 50MG/G PDA 30G (TIABENDAZOL)",
#       "margin": 1.5235943775100402
#     },
#     {
#       "sku": "P00030345",
#       "name": "DROSPIR+ETINILEST.3+0,03MG C/21CPR REV(G",
#       "margin": 0.6094594594594595
#     },
#     {
#       "sku": "P00018228",
#       "name": "NEOSEMID 40MG C/20CPR (FUROSEMIDA)",
#       "margin": 0.775946275946276
#     },
#     {
#       "sku": "P00025534",
#       "name": "ISOSSORBIDA 20MG C/30CPR (GEN)",
#       "margin": 0.44630071599045323
#     },
#     {
#       "sku": "P00027341",
#       "name": "BROMOPRIDA 10MG C/20CPS (GEN)",
#       "margin": 0.7504895104895105
#     },
#     {
#       "sku": "P00022818",
#       "name": "K-MED 50G (LUBRIFICANTE)",
#       "margin": 0.5396929824561403
#     },
#     {
#       "sku": "P00027357",
#       "name": "PARACETAMOL 200MG/ML GTS 15ML (GEN)",
#       "margin": 0.5755494505494505
#     },
#     {
#       "sku": "P00022902",
#       "name": "MAGNOSTASE 2MG C/12CPR (LOPERAMIDA)",
#       "margin": 0.607352222765022
#     },
#     {
#       "sku": "P00029505",
#       "name": "ONCICREM A 1MG/G PDA BUCAL 10G (TRIANCIN",
#       "margin": 0.5931470392548238
#     },
#     {
#       "sku": "P00018613",
#       "name": "LIDIAL 50MG/G PDA 25G (LIDOCAINA)",
#       "margin": 0.7238605898123325
#     },
#     {
#       "sku": "P00018694",
#       "name": "CORTICORTEN  5MG C/20CPR (PREDNISONA)",
#       "margin": 0.6592944222677742
#     },
#     {
#       "sku": "P00018695",
#       "name": "CORTICORTEN 20MG C/20CPR (PREDNISONA)",
#       "margin": 0.6269380991833353
#     },
#     {
#       "sku": "P00027478",
#       "name": "MOMETASONA 1MG/G PDA 20G (GEN)",
#       "margin": 0.5657142857142857
#     },
#     {
#       "sku": "P00032043",
#       "name": "SERTRALINA  50MG C/28CPR REV-GEN (C1)",
#       "margin": 0.5926294820717133
#     },
#     {
#       "sku": "P00019223",
#       "name": "CLEARTOP 20MG/G CR 30G (CETOCONAZOL)",
#       "margin": 0.6064487632508834
#     },
#     {
#       "sku": "P00031617",
#       "name": "QUETIAPINA  25MG C/30CPR REV-GEN (C1)",
#       "margin": 0.6813988095238096
#     },
#     {
#       "sku": "P00031632",
#       "name": "TIAPLEX 50MG/G PDA 20G (TIABENDAZOL)",
#       "margin": 0.6126453488372092
#     },
#     {
#       "sku": "P00030767",
#       "name": "SIMETICONA  75MG/ML GTS 10ML",
#       "margin": 0.8140495867768595
#     },
#     {
#       "sku": "P00030815",
#       "name": "OCYLIN 500MG C/15CPS",
#       "margin": 0.8049751243781097
#     },
#     {
#       "sku": "P00023776",
#       "name": "PREDNISONA 20MG C/10CPR (GEN)",
#       "margin": 0.6978092783505155
#     },
#     {
#       "sku": "P00029755",
#       "name": "IBUPROFENO 100MG/ML GTS 20ML (GEN)",
#       "margin": 0.7433333333333334
#     },
#     {
#       "sku": "P00023826",
#       "name": "IPRATROPIO 0,25MG/ML SOL INAL 20ML (GEN)",
#       "margin": 0.6307070707070708
#     },
#     {
#       "sku": "P00029869",
#       "name": "BROMOPRIDA 10MG C/20CPS (GEN)",
#       "margin": 0.6514893617021276
#     },
#     {
#       "sku": "P00028308",
#       "name": "ASSEPMED 1% SPRAY 50ML (CLOREXIDINA)",
#       "margin": 0.3851224105461395
#     },
#     {
#       "sku": "P00024245",
#       "name": "HYSTIN 2MG C/20CPR (DEXCLORFENIRAMINA)",
#       "margin": 0.8543346774193549
#     },
#     {
#       "sku": "P00024266",
#       "name": "TRAXONOL 100MG C/ 4CPS (ITRACONAZOL)",
#       "margin": 0.814723320158103
#     },
#     {
#       "sku": "P00026377",
#       "name": "ARLIVRY 7MG/ML XPE 100ML-CEREJA (EXPECT",
#       "margin": 0.7081081081081081
#     },
#     {
#       "sku": "P00026378",
#       "name": "ARLIVRY 7MG/ML XPE 100ML-MEL (EXPECTORAN",
#       "margin": 0.7418386491557224
#     },
#     {
#       "sku": "P00029961",
#       "name": "IBUVIX 600MG C/20CPR REV (IBUPROFENO)",
#       "margin": 0.555
#     },
#     {
#       "sku": "P00032200",
#       "name": "DEXTAMINE C/20CPR (DEXCLORF+BETAMETASONA",
#       "margin": 0.662037037037037
#     },
#     {
#       "sku": "P00031102",
#       "name": "FRUSALT PO EFERV 100G",
#       "margin": 0.33131313131313134
#     },
#     {
#       "sku": "P00030072",
#       "name": "DROSPIR+ETINILEST.3+0,03MG C/21CPR REV(G",
#       "margin": 0.5949962377727614
#     },
#     {
#       "sku": "P00032594",
#       "name": "PREDNISOLONA 3MG/ML SOL OR  60ML+CP(GEN)",
#       "margin": 0.6837606837606839
#     },
#     {
#       "sku": "P00031952",
#       "name": "CIPROFLOXACINO 500MG C/14CPR REV (GEN)",
#       "margin": 0.7769423558897242
#     },
#     {
#       "sku": "P00024272",
#       "name": "VITACIN 200MG/ML GTS 20ML (VIT.C)",
#       "margin": 0.6144385026737966
#     },
#     {
#       "sku": "P00029756",
#       "name": "LORATADINA 10MG C/12CPR (GEN)",
#       "margin": 0.5399408284023668
#     },
#     {
#       "sku": "P00029879",
#       "name": "ACETILCISTEINA 600MG GRAN 16ENV 5G (GEN)",
#       "margin": 0.6601510734163795
#     },
#     {
#       "sku": "P00029772",
#       "name": "PROPOLIGHT SPRAY 35ML PROP/CRAVO/CANELA",
#       "margin": 0.5835010060362174
#     },
#     {
#       "sku": "P00029776",
#       "name": "PROPOLIGHT SPRAY 35ML PROP/MALVA/MENTA",
#       "margin": 0.7364185110663986
#     },
#     {
#       "sku": "P00018180",
#       "name": "PROPOLIS 30% SPRAY 35ML MEL/MENTA",
#       "margin": 0.9069493521790342
#     },
#     {
#       "sku": "P00018179",
#       "name": "PROPOLIS 20% SPRAY 35ML  MEL/MENTA",
#       "margin": 0.8067961165048544
#     },
#     {
#       "sku": "P00018328",
#       "name": "DORALGINA C/100DRG-25X04(ISOMET+DIPIR+CA",
#       "margin": 0.5781007220546568
#     },
#     {
#       "sku": "P00025264",
#       "name": "SUNDOWN FISH OIL 1000MG C/180CPS",
#       "margin": 0.7422872340425533
#     },
#     {
#       "sku": "P00028858",
#       "name": "SUNDOWN FISH OIL 1000MG C/320CPS(OL.PEIX",
#       "margin": 0.7421810359093166
#     },
#     {
#       "sku": "P00025161",
#       "name": "SUNDOWN FISH OIL 1000MG C/120CPS",
#       "margin": 0.7421481194261342
#     },
#     {
#       "sku": "P00025214",
#       "name": "SUNDOWN MAGNESIUM OXIDE 250MG C/100TABEL",
#       "margin": 0.7421820708825572
#     },
#     {
#       "sku": "P00029696",
#       "name": "RESFENOL C/240CPS-48X5 (PARAC+FENILEF+CL",
#       "margin": 0.588525641025641
#     },
#     {
#       "sku": "P00030083",
#       "name": "TORSILAX 200CPR-20X10 (PARAC+DICLOF+CAR+",
#       "margin": 0.594942213814323
#     },
#     {
#       "sku": "P00022649",
#       "name": "NISTATINA CR VAG 60G+APL (GEN)",
#       "margin": 0.5856125678119348
#     },
#     {
#       "sku": "P00029567",
#       "name": "NISTATINA CR VAG 60G+14APL (GEN)",
#       "margin": 0.43025335320417285
#     },
#     {
#       "sku": "P00024632",
#       "name": "POLARADEX 0,4MG/ML XPE 100ML (DEXCLORFEN",
#       "margin": 0.700095510983763
#     },
#     {
#       "sku": "P00024629",
#       "name": "MAXALGINA 50MG/ML SOL INF 100ML (DIPIRON",
#       "margin": 0.71293959279825
#     },
#     {
#       "sku": "P00019551",
#       "name": "DRAMAVIT B6 25/5MG/ML GTS 20ML(VIT.B6+DI",
#       "margin": 0.586160884483416
#     },
#     {
#       "sku": "P00019228",
#       "name": "CIFLOGEX C/12PAST-MENTA/LIMAO (BENZIDAM.",
#       "margin": 0.5355829831932774
#     },
#     {
#       "sku": "P00022778",
#       "name": "CASPACIL 25MG/ML SHAM 100ML(SULF.SELENIO",
#       "margin": 0.7165805168986084
#     },
#     {
#       "sku": "P00027371",
#       "name": "CICLOPIROX OLAMINA 10MG/ML SOL 15ML (GEN",
#       "margin": 1.0380549682875262
#     },
#     {
#       "sku": "P00014352",
#       "name": "DELTAPIL 0,2MG/ML LOCAO 100ML (DELTAMETR",
#       "margin": 0.7882530120481929
#     },
#     {
#       "sku": "P00014351",
#       "name": "DELTAPIL 0,2MG/ML SHAMPOO 100ML (DELTAM",
#       "margin": 0.7755185749443337
#     },
#     {
#       "sku": "P00025602",
#       "name": "SUAVICID CR 15G (HIDROQ+TRETIN+FLUOCIN)",
#       "margin": 0.6511
#     },
#     {
#       "sku": "P00018996",
#       "name": "AFOPIC 5MG C/20CPR (ACIDO FOLICO)",
#       "margin": 0.6279279279279278
#     },
#     {
#       "sku": "P00024717",
#       "name": "OLEO MINERAL 100ML FARMAX",
#       "margin": 0.6635220125786163
#     },
#     {
#       "sku": "P00025543",
#       "name": "PHITOSS 7MG/ML XPE 100ML (HEDERA HELIX L",
#       "margin": 0.7052896725440807
#     },
#     {
#       "sku": "P00025359",
#       "name": "KALONAT 10ML (AC.SALICILICO/LACTICO)",
#       "margin": 1.1694194919347047
#     },
#     {
#       "sku": "P00018907",
#       "name": "MASSAGEOL PDA 15G (SALIC.MET+ASSOC.",
#       "margin": 0.5049312404500625
#     },
#     {
#       "sku": "P00032689",
#       "name": "TESTOPRO 500 C/60CPS (POLIVIT+POLIM)",
#       "margin": 1.6319543509272467
#     },
#     {
#       "sku": "P00022331",
#       "name": "AMBROXMEL 6MG/ML XPE AD 120ML (AMBROXOL)",
#       "margin": 0.6213235294117648
#     },
#     {
#       "sku": "P00023913",
#       "name": "PREDNISONA 20MG C/10CPR (GEN)",
#       "margin": 0.5105485232067509
#     },
#     {
#       "sku": "P00014336",
#       "name": "NEUTOSS 0,48MG/ML XPE 100ML (SALBUTAMOL)",
#       "margin": 1.4701298701298704
#     },
#     {
#       "sku": "P00032761",
#       "name": "INDAPAMIDA 1,5MG C/30CPR REV LIB PR(GEN)",
#       "margin": 0.551093439363817
#     },
#     {
#       "sku": "P00028932",
#       "name": "TANSULOSINA 0,4MG C/20CPS (GEN)",
#       "margin": 0.5981743903995915
#     },
#     {
#       "sku": "P00031077",
#       "name": "OMENAX 40MG C/28CPS (OMEPRAZOL)",
#       "margin": 0.9343929254302101
#     },
#     {
#       "sku": "P00024248",
#       "name": "LANZOPEPT 30MG C/28CPS LIB RET (LANSOPR",
#       "margin": 0.5576402321083173
#     },
#     {
#       "sku": "P00025446",
#       "name": "CEFALEXINA 500MG C/10CPR (GEN)",
#       "margin": 0.619062244062244
#     },
#     {
#       "sku": "P00028561",
#       "name": "DOMPERIDONA 10MG C/30CPR (GEN)",
#       "margin": 0.7300785634118969
#     },
#     {
#       "sku": "P00028877",
#       "name": "CAPTOPRIL 25MG C/30CPR (GEN)",
#       "margin": 0.5313725490196078
#     },
#     {
#       "sku": "P00025981",
#       "name": "HIDROCORTISONA 10MG/G CR 30G (GEN)",
#       "margin": 0.3938162942902279
#     },
#     {
#       "sku": "P00023216",
#       "name": "AMINOFILINA 100MG C/20CPR (GEN)",
#       "margin": 0.5757142857142857
#     },
#     {
#       "sku": "P00028937",
#       "name": "CISTEIL 200MG C/16ENV 5G (ACETILCISTEINA",
#       "margin": 0.37861180904522607
#     },
#     {
#       "sku": "P00029588",
#       "name": "CISTEIL 40MG/ML XPE 120ML+CP (ACETILCIST",
#       "margin": 0.5436656671664168
#     },
#     {
#       "sku": "P00029586",
#       "name": "CISTEIL 600MG GRAN C/16ENV 5G (ACETILCIS",
#       "margin": 0.514216575922565
#     },
#     {
#       "sku": "P00029530",
#       "name": "GINO MIZONOL 20MG/G CR VAG 80G+14APL",
#       "margin": 0.4484737586292939
#     },
#     {
#       "sku": "P00019612",
#       "name": "METOCLOPRAMIDA 4MG/ML GTS 10ML (GEN)",
#       "margin": 0.5810162991371045
#     },
#     {
#       "sku": "P00031241",
#       "name": "ALIVIOL ICE AEROSSOL 120ML (ARNICA)",
#       "margin": 0.6770636420919975
#     },
#     {
#       "sku": "P00026102",
#       "name": "BISURAN 1,6MG/ML XPE AD 120ML-CEREJA",
#       "margin": 0.6845238095238096
#     },
#     {
#       "sku": "P00032767",
#       "name": "CLEANCO SPRAY 25ML-CAPIM LIMAO",
#       "margin": 1.4161290322580646
#     },
#     {
#       "sku": "P00022005",
#       "name": "FLAVONID 450/50MG C/30CPR REV(DIOSM+HESP",
#       "margin": 0.5399476492499747
#     },
#     {
#       "sku": "P00020380",
#       "name": "GRIPEOL SOL OR 100ML(PARAC+FENILEF+CLORF",
#       "margin": 0.6120481927710841
#     },
#     {
#       "sku": "P00026134",
#       "name": "HIDRAPLEX PO 27,9G C/4ENV-GUARANA (REIDR",
#       "margin": 0.6867446767696145
#     },
#     {
#       "sku": "P00028646",
#       "name": "IBUFRAN 400MG C/ 10CPR (IBUPROFENO)",
#       "margin": 0.49561403508771934
#     },
#     {
#       "sku": "P00032806",
#       "name": "CURCUMA VEGAN 400MG C/60CPS-KATIGUA",
#       "margin": 0.6821473158551811
#     },
#     {
#       "sku": "P00029630",
#       "name": "NASOJET 0,9% AEROS 100ML-JATO CONT",
#       "margin": 0.5614910659272951
#     },
#     {
#       "sku": "P00029604",
#       "name": "NEOCOFLAN 11,6MG AER 85ML(DICLOF.DIETIL",
#       "margin": 0.6160260172143975
#     },
#     {
#       "sku": "P00025022",
#       "name": "NEOSORO H 3% SOL NASAL 60ML (CLOR.SODIO)",
#       "margin": 0.5381823461091753
#     },
#     {
#       "sku": "P00018459",
#       "name": "TANDERALGIN C/12CPR(PARAC+DICLOF+CARIS+C",
#       "margin": 0.6540448722485668
#     },
#     {
#       "sku": "P00029765",
#       "name": "PANTOPRAZOL 40MG C/28CPR REV (GEN)",
#       "margin": 0.5789214479192317
#     },
#     {
#       "sku": "P00029720",
#       "name": "SILDENAFILA  50MG C/4CPR REV (GEN)",
#       "margin": 0.4968220338983052
#     },
#     {
#       "sku": "P00032403",
#       "name": "CRISTAL GENGIBRE C/6U-SAB.CRAVO/CANELA",
#       "margin": 3.142857142857143
#     },
#     {
#       "sku": "P00023217",
#       "name": "AMINOFILINA 200MG C/20CPR (GEN)",
#       "margin": 0.41966527196652714
#     },
#     {
#       "sku": "P00019610",
#       "name": "DEXAMETASONA 0,1MG/ML ELX 100ML (GEN)",
#       "margin": 0.6770186335403727
#     },
#     {
#       "sku": "P00013439",
#       "name": "HELMIZOL 250MG C/20CPR (METRONIDAZOL)",
#       "margin": 0.5245958032335742
#     },
#     {
#       "sku": "P00031060",
#       "name": "METRONIDAZOL 100MG/G GEL VAG 50G+10APL(G",
#       "margin": 0.4801526717557252
#     },
#     {
#       "sku": "P00024271",
#       "name": "TRAXONOL 100MG C/15CPS (ITRACONAZOL)",
#       "margin": 0.9153277931671283
#     },
#     {
#       "sku": "P00025606",
#       "name": "ASSEPTCARE 10MG/ML SPRAY 50ML(CLOREXIDIN",
#       "margin": 0.5955710955710957
#     },
#     {
#       "sku": "P00030329",
#       "name": "COLCHICINA 0,5MG C/20CPR (GEN)",
#       "margin": 0.6537102473498232
#     },
#     {
#       "sku": "P00028075",
#       "name": "CICATRISAN A.G.E. 200ML-ALMOT(OLEO GIRAS",
#       "margin": 0.9823793755912962
#     },
#     {
#       "sku": "P00027730",
#       "name": "DORILEN GTS 20ML (DIPIRONA+ADIFEN+PROMET",
#       "margin": 0.7080015536997475
#     },
#     {
#       "sku": "P00025582",
#       "name": "NORMOLAX XPE 120ML-AMEIXA (LACTULOSE)",
#       "margin": 0.7396745932415519
#     },
#     {
#       "sku": "P00032074",
#       "name": "NINHO 1+ PREBIO 1 FASES LEPO PO 800G",
#       "margin": 0.10861023798832506
#     },
#     {
#       "sku": "P00029589",
#       "name": "IBUVIX 300MG C/20CPR (IBUPROFENO)",
#       "margin": 0.3733200597312096
#     },
#     {
#       "sku": "P00011244",
#       "name": "APEVITIN BC XPE 240ML (POLIVIT+ASSOCIAC",
#       "margin": 0.3527391975308642
#     },
#     {
#       "sku": "P00031401",
#       "name": "COMPLEXO B GTS 30ML (VIT.COMPL.B)",
#       "margin": 0.8384955752212391
#     },
#     {
#       "sku": "P00014015",
#       "name": "DERMOBENE 10MG/G CR 20G (CLOTRIMAZOL)",
#       "margin": 0.8751623376623376
#     },
#     {
#       "sku": "P00028647",
#       "name": "IBUFRAN 300MG C/ 20CPR (IBUPROFENO)",
#       "margin": 0.23615819209039557
#     },
#     {
#       "sku": "P00030054",
#       "name": "LACTUGOLD 667MG/ML SOL OR 120ML-FR.VERM",
#       "margin": 0.7505844155844156
#     },
#     {
#       "sku": "P00026143",
#       "name": "NASOJET 0,9% SPR NAS 50ML (CLOR.SODIO)",
#       "margin": 0.67513080947984
#     },
#     {
#       "sku": "P00019924",
#       "name": "REPOFLOR 200MG PED 4SACH.1G(REP.FLOR.INT",
#       "margin": 0.6280107973421927
#     },
#     {
#       "sku": "P00031670",
#       "name": "ACNOL SABONETE 80G (ENXOFRE)",
#       "margin": 0.6926129426129426
#     },
#     {
#       "sku": "P00019742",
#       "name": "TANDERALGIN C/30CPR (PARAC+DICLOF+CAR+CA",
#       "margin": 0.5823586744639377
#     },
#     {
#       "sku": "P00025087",
#       "name": "TYLEMAX BABY 100MG/ML SUSP 15ML-FRUT(PAR",
#       "margin": 0.9440412528647822
#     },
#     {
#       "sku": "P00022006",
#       "name": "VERTIGIUM 10MG C/50CPR (FLUNARIZINA)",
#       "margin": 0.3931377115354757
#     },
#     {
#       "sku": "P00026146",
#       "name": "VITAMIN E 400MG C/30CPS (VIT.E)",
#       "margin": 0.7389449503650832
#     },
#     {
#       "sku": "P00025980",
#       "name": "HIDROCORTISONA 10MG/G CR 15G (GEN)",
#       "margin": 0.42194787379972576
#     },
#     {
#       "sku": "P00028546",
#       "name": "FLUITEINA 600MG C/16ENV 5G (ACETILCIS",
#       "margin": 0.11509101585437446
#     },
#     {
#       "sku": "P00019441",
#       "name": "NEO FOLICO 5MG C/20CPR REV (ACIDO FOLICO",
#       "margin": 0.6942077020202021
#     },
#     {
#       "sku": "P00019198",
#       "name": "NEOCOFLAN 11,6MG/G GEL 60G(DICLOF.DIETIL",
#       "margin": 0.5450657894736841
#     },
#     {
#       "sku": "P00027673",
#       "name": "NEODIA 1,5MG C/1CPR (PILULA D/S)",
#       "margin": 0.6829573934837091
#     },
#     {
#       "sku": "P00029656",
#       "name": "UNHAGOLD SPRAY 30ML (AC.SALICILICO+ASSOC",
#       "margin": 0.659700452803901
#     },
#     {
#       "sku": "P00032402",
#       "name": "CRISTAL GENGIBRE C/6U-SAB.LIMAO/SAL LIGH",
#       "margin": 2.7561260210035003
#     },
#     {
#       "sku": "P00032337",
#       "name": "CALMASYN 37,84MG/ML SOL OR 100ML+CP(PASS",
#       "margin": 0.4755555555555555
#     },
#     {
#       "sku": "P00026019",
#       "name": "ITRALEX 100MG C/15CPS (ITRACONAZOL)",
#       "margin": 0.9934188034188034
#     },
#     {
#       "sku": "P00030053",
#       "name": "LACTUGOLD 667MG/ML SOL OR 120ML-AMEIXA",
#       "margin": 0.4357494613727301
#     },
#     {
#       "sku": "P00028326",
#       "name": "MAGMAX 100ML HORTELA (LEITE DE MAGNESIA)",
#       "margin": 0.5603864734299517
#     },
#     {
#       "sku": "P00032145",
#       "name": "METRONIDAZOL 250MG C/20CPR (GEN)",
#       "margin": 0.34177215189873417
#     },
#     {
#       "sku": "P00019686",
#       "name": "MICONAZOL 20MG/G CR VAG 80G+14APL (GEN)",
#       "margin": 0.5789931350114417
#     },
#     {
#       "sku": "P00031050",
#       "name": "TRIANCINOLONA 1MG/G PDA BUCAL 10G (GEN)",
#       "margin": 0.174863387978142
#     },
#     {
#       "sku": "P00028230",
#       "name": "BUPROVIL 300MG C/ 20CPR REV (IBUPROFENO)",
#       "margin": 0.43042553191489363
#     },
#     {
#       "sku": "P00028051",
#       "name": "HIDRALYTE SOL OR 500ML-AGUA COCO (REIDR",
#       "margin": 0.6905940594059405
#     },
#     {
#       "sku": "P00028055",
#       "name": "HIDRALYTE SOL OR 500ML-UVA (REIDR",
#       "margin": 0.6310588235294118
#     },
#     {
#       "sku": "P00025599",
#       "name": "SUAVICID CR 30G (HIDROQ+TRETIN+FLUOCIN)",
#       "margin": 0.5353970016657411
#     },
#     {
#       "sku": "P00032210",
#       "name": "COLIAFT 1MG/G PASTA BUCAL 10G (TRIANCIN",
#       "margin": 0.6721311475409837
#     },
#     {
#       "sku": "P00011217",
#       "name": "EXPECTUSS 3MG/ML XPE PED 100ML(AMBROXOL)",
#       "margin": 1.1967905405405406
#     },
#     {
#       "sku": "P00010585",
#       "name": "HIPODERMON PDA 45G (OXIDO ZINCO+VIT.A/D)",
#       "margin": 0.666051660516605
#     },
#     {
#       "sku": "P00018153",
#       "name": "MUCOXOLAN 6MG/ML XPE AD 120ML (AMBROXOL)",
#       "margin": 0.5700934579439253
#     },
#     {
#       "sku": "P00018152",
#       "name": "MUCOXOLAN 3MG/ML XPE PED 120ML(AMBROXOL)",
#       "margin": 0.42692307692307685
#     },
#     {
#       "sku": "P00022727",
#       "name": "TIBIAL 2,5MG C/28CPR (TIBOLONA)",
#       "margin": 0.5829408686551545
#     },
#     {
#       "sku": "P00025860",
#       "name": "PREDNISONA 20MG C/10CPR (GEN)",
#       "margin": 0.5435656836461126
#     },
#     {
#       "sku": "P00011290",
#       "name": "COMPLEXO B EMS C/ 20CPR REV (VIT.COMPL.B",
#       "margin": 0.7231851549755303
#     },
#     {
#       "sku": "P00026348",
#       "name": "METFORMINA 500MG C/30CPR (GEN)",
#       "margin": 0.010446343779677144
#     },
#     {
#       "sku": "P00023322",
#       "name": "FORMYN 850MG C/30CPR REV (METFORMINA)",
#       "margin": 0.49545772187281645
#     },
#     {
#       "sku": "P00029594",
#       "name": "IBUPROFENO 100MG/ML GTS 20ML (GEN)",
#       "margin": 0.44943693693693704
#     },
#     {
#       "sku": "P00030248",
#       "name": "IBUPROTRAT 50MG/ML GTS 30ML (IBUPROFEN",
#       "margin": 0.578034682080925
#     },
#     {
#       "sku": "P00020235",
#       "name": "FLUCOL 150MG C/2CPS (FLUCONAZOL)",
#       "margin": 0.7974683544303796
#     },
#     {
#       "sku": "P00027006",
#       "name": "NASALFREE 0,9% SPR NAS 50ML (CLOR.SODIO)",
#       "margin": 0.5641534391534391
#     },
#     {
#       "sku": "P00030752",
#       "name": "PARACETAMOL 200MG/ML GTS 15ML (GEN)",
#       "margin": 0.6588235294117646
#     },
#     {
#       "sku": "P00031519",
#       "name": "CIPROFIBRATO 100MG C/30CPR (GEN)",
#       "margin": 0.6148964595858383
#     },
#     {
#       "sku": "P00027793",
#       "name": "DENTAL FRESH PERIOTRAT 250ML-MENTA",
#       "margin": 0.5282167042889392
#     },
#     {
#       "sku": "P00012218",
#       "name": "HEPATILON SOL OR 150ML (BOLDO)",
#       "margin": 0.8493771774924833
#     },
#     {
#       "sku": "P00030654",
#       "name": "VIOLETA GENCIANA 1% SOL 30ML FARMAX",
#       "margin": 1.0450980392156861
#     },
#     {
#       "sku": "P00024208",
#       "name": "NISTATINA SUSP OR 50ML (GEN)",
#       "margin": 0.7451697127937337
#     },
#     {
#       "sku": "P00022136",
#       "name": "DEXMINE XPE 120ML(DEXCLORF+BETAMETASONA)",
#       "margin": 0.9594706368899919
#     },
#     {
#       "sku": "P00022197",
#       "name": "AERODINI SPRAY 200 DOSES (SALBUTAMOL)",
#       "margin": 0.5281497600714207
#     },
#     {
#       "sku": "P00026300",
# ...
#       "name": "NATURALIS MANIP DROG",
#       "orderCount": 1,
#       "orderTotal": 108.81
#     },
#     {
#       "id": 66285,
#       "name": "DROG. 3 IRMAOS",
#       "orderCount": 1,
#       "orderTotal": 0
#     },
#     {
#       "id": 66285,
#       "name": "DROG. GASPAR",
#       "orderCount": 1,
#       "orderTotal": 804.15
#     },
#     {
#       "id": 66285,
#       "name": "FCIA NOSSA SRA APARE",
#       "orderCount": 1,
#       "orderTotal": 402.49
#     },
#     {
#       "id": 66285,
#       "name": "CEMED",
#       "orderCount": 2,
#       "orderTotal": 2618.77
#     },
#     {
#       "id": 66285,
#       "name": "FARMA BERTHA",
#       "orderCount": 1,
#       "orderTotal": 1016.9799999999997
#     },
#     {
#       "id": 66285,
#       "name": "REDFARMA",
#       "orderCount": 1,
#       "orderTotal": 868.3100000000002
#     },
#     {
#       "id": 66285,
#       "name": "DROGALITA PARAISO",
#       "orderCount": 1,
#       "orderTotal": 802.74
#     },
#     {
#       "id": 66285,
#       "name": "DROG. NACIONAL",
#       "orderCount": 2,
#       "orderTotal": 652.6399999999999
#     },
#     {
#       "id": 66285,
#       "name": "REDE FARMA HOME LAPA",
#       "orderCount": 2,
#       "orderTotal": 3800.4400000000014
#     },
#     {
#       "id": 66285,
#       "name": "DROG ULTRA POPULAR",
#       "orderCount": 1,
#       "orderTotal": 929.8699999999999
#     },
#     {
#       "id": 66285,
#       "name": "FCIA STA LUZIA",
#       "orderCount": 1,
#       "orderTotal": 1050.73
#     },
#     {
#       "id": 66285,
#       "name": "DROG. NOVA",
#       "orderCount": 1,
#       "orderTotal": 211.48999999999998
#     },
#     {
#       "id": 66285,
#       "name": "DROG. EDUARDO MARCAL",
#       "orderCount": 1,
#       "orderTotal": 1524.9300000000005
#     },
#     {
#       "id": 66285,
#       "name": "FCIA N. SRA APARECID",
#       "orderCount": 1,
#       "orderTotal": 835.0
#     },
#     {
#       "id": 66285,
#       "name": "FARMAJATO",
#       "orderCount": 1,
#       "orderTotal": 2382.83
#     },
#     {
#       "id": 66285,
#       "name": "DROG. POPULAR MELHOR",
#       "orderCount": 1,
#       "orderTotal": 1140.27
#     },
#     {
#       "id": 66285,
#       "name": "DROGARIA TOTAL",
#       "orderCount": 1,
#       "orderTotal": 103.6
#     },
#     {
#       "id": 66285,
#       "name": "NOVA FARMA",
#       "orderCount": 1,
#       "orderTotal": 724.5600000000002
#     },
#     {
#       "id": 66285,
#       "name": "DROG. PARQUE PIRAJUS",
#       "orderCount": 3,
#       "orderTotal": 2848.5
#     },
#     {
#       "id": 66285,
#       "name": "CAASP",
#       "orderCount": 1,
#       "orderTotal": 1282.9299999999996
#     },
#     {
#       "id": 66285,
#       "name": "CAASP - OSASCO",
#       "orderCount": 1,
#       "orderTotal": 835.83
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SAO PAULO III",
#       "orderCount": 1,
#       "orderTotal": 1109.93
#     },
#     {
#       "id": 66285,
#       "name": "DROG. BELA CEREJEIRA",
#       "orderCount": 1,
#       "orderTotal": 810.9300000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. JARDIM GONCALV",
#       "orderCount": 2,
#       "orderTotal": 1781.3400000000001
#     },
#     {
#       "id": 66285,
#       "name": "MEDMASTER COMERCIAL",
#       "orderCount": 1,
#       "orderTotal": 787.2299999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SANTA PAULA",
#       "orderCount": 1,
#       "orderTotal": 776.9399999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SETE DE SETEMB",
#       "orderCount": 1,
#       "orderTotal": 568.8900000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROGAMAX",
#       "orderCount": 1,
#       "orderTotal": 719.82
#     },
#     {
#       "id": 66285,
#       "name": "MED FARMA",
#       "orderCount": 1,
#       "orderTotal": 491.43999999999994
#     },
#     {
#       "id": 66285,
#       "name": "DROGARIA SAO PEDRO 2",
#       "orderCount": 2,
#       "orderTotal": 1813.2799999999997
#     },
#     {
#       "id": 66285,
#       "name": "DROG. FARMINAS",
#       "orderCount": 3,
#       "orderTotal": 5707.200000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SAO ROQUE",
#       "orderCount": 1,
#       "orderTotal": 790.3800000000003
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SAO JOSE",
#       "orderCount": 2,
#       "orderTotal": 1407.44
#     },
#     {
#       "id": 66285,
#       "name": "UNIMED DE LINS COOP",
#       "orderCount": 1,
#       "orderTotal": 942.3999999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. PORTUGUES",
#       "orderCount": 1,
#       "orderTotal": 955.17
#     },
#     {
#       "id": 66285,
#       "name": "CAASP - CAMPINAS",
#       "orderCount": 1,
#       "orderTotal": 1051.64
#     },
#     {
#       "id": 66285,
#       "name": "FARMAVIDA",
#       "orderCount": 1,
#       "orderTotal": 700.1800000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. GLORIA",
#       "orderCount": 1,
#       "orderTotal": 991.6600000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. DROGA NOVA",
#       "orderCount": 1,
#       "orderTotal": 906.74
#     },
#     {
#       "id": 66285,
#       "name": "QUALYFARMA",
#       "orderCount": 1,
#       "orderTotal": 732.4000000000002
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SARAPUI",
#       "orderCount": 2,
#       "orderTotal": 4312.66
#     },
#     {
#       "id": 66285,
#       "name": "FARMAIS GUAIANASES I",
#       "orderCount": 1,
#       "orderTotal": 711.3000000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. BATISTINI",
#       "orderCount": 1,
#       "orderTotal": 1574.6799999999998
#     },
#     {
#       "id": 66285,
#       "name": "DROGAHORTO",
#       "orderCount": 1,
#       "orderTotal": 488.29999999999995
#     },
#     {
#       "id": 66285,
#       "name": "FCIA CENTRAL",
#       "orderCount": 1,
#       "orderTotal": 759.0799999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. 15 - REDE TOT",
#       "orderCount": 1,
#       "orderTotal": 1081.1200000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. AMERICANA 10",
#       "orderCount": 1,
#       "orderTotal": 438.99999999999994
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SHALON 1",
#       "orderCount": 1,
#       "orderTotal": 762.2700000000001
#     },
#     {
#       "id": 66285,
#       "name": "FCIA SAO JOAO",
#       "orderCount": 1,
#       "orderTotal": 829.6900000000002
#     },
#     {
#       "id": 66285,
#       "name": "DROG. FARMACENTRO",
#       "orderCount": 1,
#       "orderTotal": 896.09
#     },
#     {
#       "id": 66285,
#       "name": "DROG. CENTRAL",
#       "orderCount": 1,
#       "orderTotal": 545.3399999999999
#     },
#     {
#       "id": 66285,
#       "name": "MEDPRIME",
#       "orderCount": 1,
#       "orderTotal": 1411.41
#     },
#     {
#       "id": 66285,
#       "name": "MEDPHARMA",
#       "orderCount": 3,
#       "orderTotal": 3187.75
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SANTA HELENA",
#       "orderCount": 1,
#       "orderTotal": 787.8
#     },
#     {
#       "id": 66285,
#       "name": "POPULAR FARMA",
#       "orderCount": 2,
#       "orderTotal": 3226.3599999999997
#     },
#     {
#       "id": 66285,
#       "name": "SAUDE FARMA",
#       "orderCount": 1,
#       "orderTotal": 1688.4
#     },
#     {
#       "id": 66285,
#       "name": "FCIA NOSSA SRA APARE",
#       "orderCount": 1,
#       "orderTotal": 760.29
#     },
#     {
#       "id": 66285,
#       "name": "OUROFARMA",
#       "orderCount": 1,
#       "orderTotal": 797.7
#     },
#     {
#       "id": 66285,
#       "name": "DROG. AMERICA",
#       "orderCount": 2,
#       "orderTotal": 1656.8400000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. STA HELENA",
#       "orderCount": 1,
#       "orderTotal": 792.8600000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROGA INDEPENDENCIA",
#       "orderCount": 1,
#       "orderTotal": 828.8900000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROGARIA PIRITUBA",
#       "orderCount": 1,
#       "orderTotal": 780.9099999999999
#     },
#     {
#       "id": 66285,
#       "name": "DOGNANI & VAZ LTDA",
#       "orderCount": 1,
#       "orderTotal": 708.14
#     },
#     {
#       "id": 66285,
#       "name": "DROG TOTAL DROGALITA",
#       "orderCount": 1,
#       "orderTotal": 709.0899999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. BARROS FARMA",
#       "orderCount": 1,
#       "orderTotal": 858.25
#     },
#     {
#       "id": 66285,
#       "name": "GANHA SEMPRE DROG",
#       "orderCount": 1,
#       "orderTotal": 833.6899999999999
#     },
#     {
#       "id": 66285,
#       "name": "GANHA SEMPRE DROG",
#       "orderCount": 1,
#       "orderTotal": 1322.2499999999998
#     },
#     {
#       "id": 66285,
#       "name": "DROG. DORIVAL",
#       "orderCount": 1,
#       "orderTotal": 816.76
#     },
#     {
#       "id": 66285,
#       "name": "DROG HORTENSIA",
#       "orderCount": 1,
#       "orderTotal": 729.6400000000002
#     },
#     {
#       "id": 66285,
#       "name": "FCIA NOSSO LAR",
#       "orderCount": 1,
#       "orderTotal": 1458.04
#     },
#     {
#       "id": 66285,
#       "name": "FARMAIS",
#       "orderCount": 1,
#       "orderTotal": 812.9799999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. POPULAR",
#       "orderCount": 1,
#       "orderTotal": 1678.2000000000003
#     },
#     {
#       "id": 66285,
#       "name": "DROG.N.SRA APARECIDA",
#       "orderCount": 1,
#       "orderTotal": 712.3799999999998
#     },
#     {
#       "id": 66285,
#       "name": "MAMED",
#       "orderCount": 1,
#       "orderTotal": 2810.7000000000003
#     },
#     {
#       "id": 66285,
#       "name": "DROG. E PERF. SAO JU",
#       "orderCount": 1,
#       "orderTotal": 830.5199999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG.UNIAO PRIMAVERA",
#       "orderCount": 1,
#       "orderTotal": 911.0400000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. BOA SAUDE",
#       "orderCount": 1,
#       "orderTotal": 800.0099999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROGATIVA",
#       "orderCount": 1,
#       "orderTotal": 922.23
#     },
#     {
#       "id": 66285,
#       "name": "FORMULA & CIA",
#       "orderCount": 1,
#       "orderTotal": 1070.1000000000001
#     },
#     {
#       "id": 66285,
#       "name": "LUCIO FARMA",
#       "orderCount": 1,
#       "orderTotal": 780.7700000000001
#     },
#     {
#       "id": 66285,
#       "name": "CAASP - JABAQUARA",
#       "orderCount": 1,
#       "orderTotal": 4286.550000000001
#     },
#     {
#       "id": 66285,
#       "name": "PRIMULA HOM. E MAN.",
#       "orderCount": 1,
#       "orderTotal": 1673.6400000000003
#     },
#     {
#       "id": 66285,
#       "name": "IGORFARMA",
#       "orderCount": 1,
#       "orderTotal": 739.79
#     },
#     {
#       "id": 66285,
#       "name": "DROGARIA GASPAR",
#       "orderCount": 1,
#       "orderTotal": 1009.3500000000004
#     },
#     {
#       "id": 66285,
#       "name": "FCIA SAO JOSE",
#       "orderCount": 1,
#       "orderTotal": 997.98
#     },
#     {
#       "id": 66285,
#       "name": "DROG. DO TRABALHADOR",
#       "orderCount": 1,
#       "orderTotal": 777.0
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SABINO",
#       "orderCount": 1,
#       "orderTotal": 951.56
#     },
#     {
#       "id": 66285,
#       "name": "REDE POPULAR",
#       "orderCount": 1,
#       "orderTotal": 886.39
#     },
#     {
#       "id": 66285,
#       "name": "DROGARIA BOTUJURU",
#       "orderCount": 1,
#       "orderTotal": 2309.5599999999995
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SANTA BARBARA",
#       "orderCount": 1,
#       "orderTotal": 817.5099999999999
#     },
#     {
#       "id": 66285,
#       "name": "FARMAIS CAMPOS ELISE",
#       "orderCount": 1,
#       "orderTotal": 1007.5999999999999
#     },
#     {
#       "id": 66285,
#       "name": "FARMA 10",
#       "orderCount": 1,
#       "orderTotal": 730.3800000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. UNIAO",
#       "orderCount": 1,
#       "orderTotal": 800.3700000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. UNIAO",
#       "orderCount": 1,
#       "orderTotal": 0
#     },
#     {
#       "id": 66285,
#       "name": "DROG. BIOLAR",
#       "orderCount": 1,
#       "orderTotal": 825.6000000000001
#     },
#     {
#       "id": 66285,
#       "name": "FCIA PREVER",
#       "orderCount": 1,
#       "orderTotal": 1202.8299999999997
#     },
#     {
#       "id": 66285,
#       "name": "FCIA PREVER",
#       "orderCount": 1,
#       "orderTotal": 820.4499999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SAO PEDRO",
#       "orderCount": 1,
#       "orderTotal": 779.1800000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROGA MAR",
#       "orderCount": 1,
#       "orderTotal": 839.8399999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. BIOSERVE",
#       "orderCount": 1,
#       "orderTotal": 767.1500000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. JAUENSE",
#       "orderCount": 1,
#       "orderTotal": 716.8799999999999
#     },
#     {
#       "id": 66285,
#       "name": "FARMA IMPERIAL",
#       "orderCount": 1,
#       "orderTotal": 710.28
#     },
#     {
#       "id": 66285,
#       "name": "DROG. AVENIDA",
#       "orderCount": 1,
#       "orderTotal": 1175.6799999999998
#     },
#     {
#       "id": 66285,
#       "name": "FARMA SAMPA MARILIA",
#       "orderCount": 1,
#       "orderTotal": 1617.77
#     },
#     {
#       "id": 66285,
#       "name": "NOVA MELLO",
#       "orderCount": 1,
#       "orderTotal": 1291.9200000000003
#     },
#     {
#       "id": 66285,
#       "name": "CAASP - ARACATUBA",
#       "orderCount": 1,
#       "orderTotal": 1053.49
#     },
#     {
#       "id": 66285,
#       "name": "DROG. PAULISTA",
#       "orderCount": 1,
#       "orderTotal": 886.9
#     },
#     {
#       "id": 66285,
#       "name": "FARMINAS UNID III",
#       "orderCount": 1,
#       "orderTotal": 887.5000000000001
#     },
#     {
#       "id": 66285,
#       "name": "FCIA CRISTAL",
#       "orderCount": 1,
#       "orderTotal": 858.4400000000002
#     },
#     {
#       "id": 66285,
#       "name": "FCIA TIETE - REDE MU",
#       "orderCount": 1,
#       "orderTotal": 778.0699999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. PEREZ & OCANHA",
#       "orderCount": 1,
#       "orderTotal": 455.87
#     },
#     {
#       "id": 66285,
#       "name": "DROG KOTO FARMA",
#       "orderCount": 2,
#       "orderTotal": 2119.36
#     },
#     {
#       "id": 66285,
#       "name": "DROGA CENTRO",
#       "orderCount": 1,
#       "orderTotal": 743.51
#     },
#     {
#       "id": 66285,
#       "name": "DROG. CATEDRAL VIII",
#       "orderCount": 1,
#       "orderTotal": 1288.8300000000002
#     },
#     {
#       "id": 66285,
#       "name": "MAIS VIDA DROG",
#       "orderCount": 1,
#       "orderTotal": 925.88
#     },
#     {
#       "id": 66285,
#       "name": "FARMAIS SAO JOSE",
#       "orderCount": 1,
#       "orderTotal": 1147.2
#     },
#     {
#       "id": 66285,
#       "name": "DROG. BRASIL",
#       "orderCount": 1,
#       "orderTotal": 856.8699999999999
#     },
#     {
#       "id": 66285,
#       "name": "FARMAVIDA",
#       "orderCount": 1,
#       "orderTotal": 2524.0200000000004
#     },
#     {
#       "id": 66285,
#       "name": "METTA FARMA",
#       "orderCount": 1,
#       "orderTotal": 732.8899999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROGARIA VIA BRASIL",
#       "orderCount": 1,
#       "orderTotal": 1009.3199999999999
#     },
#     {
#       "id": 66285,
#       "name": "FIXFARMA",
#       "orderCount": 1,
#       "orderTotal": 811.3800000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROAGARIA NOVA FARMA",
#       "orderCount": 1,
#       "orderTotal": 1393.2
#     },
#     {
#       "id": 66285,
#       "name": "CENTRAL FARMA",
#       "orderCount": 1,
#       "orderTotal": 1230.3200000000002
#     },
#     {
#       "id": 66285,
#       "name": "FAMILY FARMA",
#       "orderCount": 1,
#       "orderTotal": 756.81
#     },
#     {
#       "id": 66285,
#       "name": "DROG. LARANJAL",
#       "orderCount": 1,
#       "orderTotal": 790.42
#     },
#     {
#       "id": 66285,
#       "name": "DROG. STO ANTONIO",
#       "orderCount": 1,
#       "orderTotal": 822.4900000000001
#     },
#     {
#       "id": 66285,
#       "name": "DROG. JARDIM AURORA",
#       "orderCount": 1,
#       "orderTotal": 708.78
#     },
#     {
#       "id": 66285,
#       "name": "DROG. SAO JUDAS TADE",
#       "orderCount": 1,
#       "orderTotal": 1590.38
#     },
#     {
#       "id": 66285,
#       "name": "DROG. CAFE",
#       "orderCount": 1,
#       "orderTotal": 1393.2
#     },
#     {
#       "id": 66285,
#       "name": "DROGALES",
#       "orderCount": 1,
#       "orderTotal": 820.9799999999999
#     },
#     {
#       "id": 66285,
#       "name": "DROG. NIPO BRASIL",
#       "orderCount": 1,
#       "orderTotal": 811.4099999999999
#     }
#   ]
# }
